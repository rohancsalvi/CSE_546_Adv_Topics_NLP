# %%
# mount GDrive to maintain a non-volatile memory of subsequent load/store operations.
# Get a runtime with GPU - needed for this assignment.
# Go to Runtime->Change runtime type->GPU
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# create an experiments folder to contain the PrimeQA related experiments.
# %cd /content/gdrive/MyDrive/
# %mkdir experiments
# %cd /content/gdrive/MyDrive/experiments
# Out:
# /content/gdrive/MyDrive
# mkdir: cannot create directory ‘experiments’: File exists
# /content/gdrive/MyDrive/experiments

# %%
# %cd /content/gdrive/MyDrive/experiments/primeqa
# Out:
# /content/gdrive/MyDrive/experiments/primeqa

# %%
#un-comment for first time use
#! git clone https://github.com/primeqa/primeqa.git

# %%
# to get latest versions of PrimeQA
# !git pull
# Out:
# Already up to date.

# %%
# move to a stable branch specifically created to give you an unchanging experience during course project timeline
# !git checkout course_project
# Out:
# M	docs/buildDocker.sh
# M	primeqa/ir/dense/colbert_top/colbert/searcher.py
# M	primeqa/ir/scripts/xortydi/convert_xorqa_jsonl_to_tsv.py
# Already on 'course_project'
# Your branch is up to date with 'origin/course_project'.

# %%
# %cd /content/gdrive/MyDrive/experiments/primeqa
# Out:
# /content/gdrive/MyDrive/experiments/primeqa

# %%
# pip install to prepare the environment. This step should take about 3-4 mins.
#Ignore if you see minor error messages below (they're because of running it in colab env)
# !pip install -e .[all]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/gdrive/MyDrive/experiments/primeqa
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting faiss-cpu~=1.7.2
#   Downloading faiss_cpu-1.7.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#      |████████████████████████████████| 8.6 MB 15.3 MB/s
# Collecting torch~=1.11.0
#   Downloading torch-1.11.0-cp37-cp37m-manylinux1_x86_64.whl (750.6 MB)
#      |████████████████████████████████| 750.6 MB 11 kB/s
# Collecting stanza~=1.4.0
#   Downloading stanza-1.4.2-py3-none-any.whl (691 kB)
#      |████████████████████████████████| 691 kB 73.8 MB/s
# Collecting nlp
#   Downloading nlp-0.4.0-py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 58.0 MB/s
# Collecting jsonlines~=3.0.0
#   Downloading jsonlines-3.0.0-py3-none-any.whl (8.5 kB)
# Collecting psutil~=5.9.0
#   Downloading psutil-5.9.4-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (280 kB)
#      |████████████████████████████████| 280 kB 74.4 MB/s
# Requirement already satisfied: packaging~=21.3 in /usr/local/lib/python3.7/dist-packages (from primeqa==0.9.4) (21.3)
# Collecting signals~=0.0.2
#   Downloading signals-0.0.2.tar.gz (1.8 kB)
# Collecting transformers~=4.17.0
#   Downloading transformers-4.17.0-py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 56.8 MB/s
# Collecting protobuf~=3.20.0
#   Downloading protobuf-3.20.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 64.1 MB/s
# Requirement already satisfied: tabulate~=0.8.9 in /usr/local/lib/python3.7/dist-packages (from primeqa==0.9.4) (0.8.10)
# Collecting bitarray~=2.3.7
#   Downloading bitarray-2.3.7.tar.gz (89 kB)
#      |████████████████████████████████| 89 kB 10.4 MB/s
# Collecting sentencepiece~=0.1.96
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 58.5 MB/s
# Requirement already satisfied: scikit-learn~=1.0.2 in /usr/local/lib/python3.7/dist-packages (from primeqa==0.9.4) (1.0.2)
# Requirement already satisfied: numpy~=1.21.5 in /usr/local/lib/python3.7/dist-packages (from primeqa==0.9.4) (1.21.6)
# Collecting pyserini~=0.16.0
#   Downloading pyserini-0.16.1-py3-none-any.whl (109.5 MB)
#      |████████████████████████████████| 109.5 MB 50 kB/s
# Collecting ninja~=1.10.2.3
#   Downloading ninja-1.10.2.4-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (120 kB)
#      |████████████████████████████████| 120 kB 77.4 MB/s
# Requirement already satisfied: pandas~=1.3.5 in /usr/local/lib/python3.7/dist-packages (from primeqa==0.9.4) (1.3.5)
# Collecting click~=8.0.4
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 8.3 MB/s
# Collecting spacy~=3.2.2
#   Downloading spacy-3.2.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      |████████████████████████████████| 6.0 MB 56.9 MB/s
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
# Collecting gitpython~=3.1.27
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 66.7 MB/s
# Collecting datasets[apache-beam]~=2.3.2
#   Downloading datasets-2.3.2-py3-none-any.whl (362 kB)
#      |████████████████████████████████| 362 kB 72.9 MB/s
# Collecting frozendict
#   Downloading frozendict-2.3.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (99 kB)
#      |████████████████████████████████| 99 kB 11.4 MB/s
# Collecting ujson~=5.1.0
#   Downloading ujson-5.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43 kB)
#      |████████████████████████████████| 43 kB 2.8 MB/s
# Requirement already satisfied: tqdm~=4.64.0 in /usr/local/lib/python3.7/dist-packages (from primeqa==0.9.4) (4.64.1)
# Requirement already satisfied: nltk~=3.7 in /usr/local/lib/python3.7/dist-packages (from primeqa==0.9.4) (3.7)
# Collecting pytest-cov~=3.0.0
#   Downloading pytest_cov-3.0.0-py3-none-any.whl (20 kB)
# Collecting ipykernel~=6.13.0
#   Downloading ipykernel-6.13.1-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 78.8 MB/s
# Collecting tox~=3.24.5
#   Downloading tox-3.24.5-py2.py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 5.5 MB/s
# Collecting sphinx~=4.4.0
#   Downloading Sphinx-4.4.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 58.7 MB/s
# Requirement already satisfied: docutils<0.18,>=0.14 in /usr/local/lib/python3.7/dist-packages (from primeqa==0.9.4) (0.17.1)
# Collecting sphinx-design~=0.2.0
#   Downloading sphinx_design-0.2.0-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 47.8 MB/s
# Collecting recommonmark~=0.7.1
#   Downloading recommonmark-0.7.1-py2.py3-none-any.whl (10 kB)
# Collecting pydata-sphinx-theme~=0.9.0
#   Downloading pydata_sphinx_theme-0.9.0-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 45.3 MB/s
# Requirement already satisfied: ipywidgets~=7.7.0 in /usr/local/lib/python3.7/dist-packages (from primeqa==0.9.4) (7.7.1)
# Collecting bump2version~=1.0.1
#   Downloading bump2version-1.0.1-py2.py3-none-any.whl (22 kB)
# Collecting faiss-gpu~=1.7.2
#   Downloading faiss_gpu-1.7.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (85.5 MB)
#      |████████████████████████████████| 85.5 MB 101 kB/s
# Collecting myst-parser~=0.17.2
#   Downloading myst_parser-0.17.2-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 3.0 MB/s
# Collecting pytest-mock~=3.7.0
#   Downloading pytest_mock-3.7.0-py3-none-any.whl (12 kB)
# Collecting pytest-rerunfailures~=10.2
#   Downloading pytest_rerunfailures-10.2-py3-none-any.whl (11 kB)
# Collecting pytest~=7.1.1
#   Downloading pytest-7.1.3-py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 77.6 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from click~=8.0.4->primeqa==0.9.4) (4.13.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 79.0 MB/s
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (6.0.1)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting xxhash
#   Downloading xxhash-3.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 73.6 MB/s
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (2022.10.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (2.23.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (3.8.3)
# Collecting huggingface-hub<1.0.0,>=0.1.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 75.6 MB/s
# Collecting dill<0.3.6
#   Downloading dill-0.3.5.1-py2.py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 5.6 MB/s
# Collecting apache-beam>=2.26.0
#   Downloading apache_beam-2.42.0-cp37-cp37m-manylinux2010_x86_64.whl (11.0 MB)
#      |████████████████████████████████| 11.0 MB 76.1 MB/s
# Collecting requests>=2.19.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.8 MB/s
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam>=2.26.0->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (1.22.1)
# Collecting cloudpickle~=2.1.0
#   Downloading cloudpickle-2.1.0-py3-none-any.whl (25 kB)
# Collecting pymongo<4.0.0,>=3.8.0
#   Downloading pymongo-3.13.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (506 kB)
#      |████████████████████████████████| 506 kB 71.4 MB/s
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam>=2.26.0->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (2.8.2)
# Collecting fastavro<2,>=0.23.6
#   Downloading fastavro-1.7.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      |████████████████████████████████| 2.4 MB 56.6 MB/s
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /usr/local/lib/python3.7/dist-packages (from apache-beam>=2.26.0->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (1.50.0)
# Collecting dill<0.3.6
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      |████████████████████████████████| 151 kB 79.4 MB/s
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.7/dist-packages (from apache-beam>=2.26.0->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (1.7)
# Requirement already satisfied: httplib2<0.21.0,>=0.8 in /usr/local/lib/python3.7/dist-packages (from apache-beam>=2.26.0->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (0.17.4)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam>=2.26.0->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (4.1.1)
# Requirement already satisfied: regex>=2020.6.8 in /usr/local/lib/python3.7/dist-packages (from apache-beam>=2.26.0->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (2022.6.2)
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading hdfs-2.7.0-py3-none-any.whl (34 kB)
# Collecting orjson<4.0
#   Downloading orjson-3.8.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (272 kB)
#      |████████████████████████████████| 272 kB 65.0 MB/s
# Collecting zstandard<1,>=0.18.0
#   Downloading zstandard-0.19.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 57.6 MB/s
# Requirement already satisfied: pytz>=2018.3 in /usr/local/lib/python3.7/dist-packages (from apache-beam>=2.26.0->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (2022.6)
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from apache-beam>=2.26.0->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (1.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (1.3.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (22.1.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (2.1.1)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (0.13.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (6.0.2)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.0 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from grpcio!=1.48.0,<2,>=1.33.1->apache-beam>=2.26.0->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (1.15.0)
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (3.8.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (6.0)
# Collecting matplotlib-inline>=0.1
#   Downloading matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.7/dist-packages (from ipykernel~=6.13.0->primeqa==0.9.4) (6.1.12)
# Collecting tornado>=6.1
#   Downloading tornado-6.2-cp37-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (423 kB)
#      |████████████████████████████████| 423 kB 69.4 MB/s
# Collecting ipython>=7.23.1
#   Downloading ipython-7.34.0-py3-none-any.whl (793 kB)
#      |████████████████████████████████| 793 kB 72.7 MB/s
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel~=6.13.0->primeqa==0.9.4) (1.0.0)
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.5.6-py3-none-any.whl (5.2 kB)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel~=6.13.0->primeqa==0.9.4) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel~=6.13.0->primeqa==0.9.4) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel~=6.13.0->primeqa==0.9.4) (0.2.0)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 61.8 MB/s
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel~=6.13.0->primeqa==0.9.4) (2.6.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel~=6.13.0->primeqa==0.9.4) (2.0.10)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel~=6.13.0->primeqa==0.9.4) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel~=6.13.0->primeqa==0.9.4) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=7.23.1->ipykernel~=6.13.0->primeqa==0.9.4) (57.4.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets~=7.7.0->primeqa==0.9.4) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets~=7.7.0->primeqa==0.9.4) (3.6.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets~=7.7.0->primeqa==0.9.4) (3.0.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel~=6.13.0->primeqa==0.9.4) (0.8.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=6.1.12->ipykernel~=6.13.0->primeqa==0.9.4) (4.11.2)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=6.1.12->ipykernel~=6.13.0->primeqa==0.9.4) (23.2.1)
# Collecting mdit-py-plugins~=0.3.0
#   Downloading mdit_py_plugins-0.3.1-py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 5.2 MB/s
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from myst-parser~=0.17.2->primeqa==0.9.4) (2.11.3)
# Collecting markdown-it-py<3.0.0,>=1.0.0
#   Downloading markdown_it_py-2.1.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 3.8 MB/s
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk~=3.7->primeqa==0.9.4) (1.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging~=21.3->primeqa==0.9.4) (3.0.9)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel~=6.13.0->primeqa==0.9.4) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel~=6.13.0->primeqa==0.9.4) (0.2.5)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from pydata-sphinx-theme~=0.9.0->primeqa==0.9.4) (4.6.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from pyserini~=0.16.0->primeqa==0.9.4) (1.7.3)
# Collecting pyjnius>=1.4.0
#   Downloading pyjnius-1.4.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 65.6 MB/s
# Collecting nmslib>=2.1.1
#   Downloading nmslib-2.1.1-cp37-cp37m-manylinux2010_x86_64.whl (13.5 MB)
#      |████████████████████████████████| 13.5 MB 51.6 MB/s
# Collecting onnxruntime>=1.8.1
#   Downloading onnxruntime-1.13.1-cp37-cp37m-manylinux_2_27_x86_64.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 60.3 MB/s
# Collecting lightgbm>=3.3.2
#   Downloading lightgbm-3.3.3-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 50.3 MB/s
# Requirement already satisfied: Cython>=0.29.21 in /usr/local/lib/python3.7/dist-packages (from pyserini~=0.16.0->primeqa==0.9.4) (0.29.32)
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from lightgbm>=3.3.2->pyserini~=0.16.0->primeqa==0.9.4) (0.38.3)
# Collecting pybind11<2.6.2
#   Downloading pybind11-2.6.1-py2.py3-none-any.whl (188 kB)
#      |████████████████████████████████| 188 kB 77.8 MB/s
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 4.5 MB/s
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.7/dist-packages (from onnxruntime>=1.8.1->pyserini~=0.16.0->primeqa==0.9.4) (1.12)
# Requirement already satisfied: sympy in /usr/local/lib/python3.7/dist-packages (from onnxruntime>=1.8.1->pyserini~=0.16.0->primeqa==0.9.4) (1.7.1)
# Collecting iniconfig
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest~=7.1.1->primeqa==0.9.4) (2.0.1)
# Requirement already satisfied: py>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from pytest~=7.1.1->primeqa==0.9.4) (1.11.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->click~=8.0.4->primeqa==0.9.4) (3.10.0)
# Collecting coverage[toml]>=5.2.1
#   Downloading coverage-6.5.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (210 kB)
#      |████████████████████████████████| 210 kB 76.5 MB/s
# Collecting commonmark>=0.8.1
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 8.8 MB/s
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets[apache-beam]~=2.3.2->primeqa==0.9.4) (1.24.3)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 74.3 MB/s
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn~=1.0.2->primeqa==0.9.4) (3.1.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from spacy~=3.2.2->primeqa==0.9.4) (3.0.10)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy~=3.2.2->primeqa==0.9.4) (0.4.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy~=3.2.2->primeqa==0.9.4) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy~=3.2.2->primeqa==0.9.4) (2.4.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy~=3.2.2->primeqa==0.9.4) (0.10.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy~=3.2.2->primeqa==0.9.4) (0.6.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy~=3.2.2->primeqa==0.9.4) (0.7.9)
# Collecting thinc<8.1.0,>=8.0.12
#   Downloading thinc-8.0.17-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (660 kB)
#      |████████████████████████████████| 660 kB 67.7 MB/s
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy~=3.2.2->primeqa==0.9.4) (1.0.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy~=3.2.2->primeqa==0.9.4) (2.0.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy~=3.2.2->primeqa==0.9.4) (2.0.8)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 60.4 MB/s
# Collecting typing-extensions>=3.7.0
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy~=3.2.2->primeqa==0.9.4) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy~=3.2.2->primeqa==0.9.4) (1.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy~=3.2.2->primeqa==0.9.4) (5.2.1)
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 11.7 MB/s
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.7/dist-packages (from sphinx~=4.4.0->primeqa==0.9.4) (0.7.12)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.7/dist-packages (from sphinx~=4.4.0->primeqa==0.9.4) (2.2.0)
# Collecting sphinxcontrib-htmlhelp>=2.0.0
#   Downloading sphinxcontrib_htmlhelp-2.0.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 11.7 MB/s
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 62.3 MB/s
# Requirement already satisfied: imagesize in /usr/local/lib/python3.7/dist-packages (from sphinx~=4.4.0->primeqa==0.9.4) (1.4.1)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.7/dist-packages (from sphinx~=4.4.0->primeqa==0.9.4) (2.11.0)
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 3.9 MB/s
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from sphinx~=4.4.0->primeqa==0.9.4) (1.1.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->myst-parser~=0.17.2->primeqa==0.9.4) (2.0.1)
# Collecting emoji
#   Downloading emoji-2.2.0.tar.gz (240 kB)
#      |████████████████████████████████| 240 kB 70.0 MB/s
# Collecting virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0
#   Downloading virtualenv-20.16.6-py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 54.4 MB/s
# Requirement already satisfied: toml>=0.9.4 in /usr/local/lib/python3.7/dist-packages (from tox~=3.24.5->primeqa==0.9.4) (0.10.2)
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 70.9 MB/s
# Collecting tokenizers!=0.11.3,>=0.11.1
#   Downloading tokenizers-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 54.2 MB/s
# Collecting platformdirs<3,>=2.4
#   Downloading platformdirs-2.5.3-py3-none-any.whl (14 kB)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      |████████████████████████████████| 468 kB 73.5 MB/s
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets~=7.7.0->primeqa==0.9.4) (5.7.16)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets~=7.7.0->primeqa==0.9.4) (1.8.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets~=7.7.0->primeqa==0.9.4) (0.13.3)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets~=7.7.0->primeqa==0.9.4) (5.7.0)
# Requirement already satisfied: nbconvert<6.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets~=7.7.0->primeqa==0.9.4) (5.6.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets~=7.7.0->primeqa==0.9.4) (0.15.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets~=7.7.0->primeqa==0.9.4) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets~=7.7.0->primeqa==0.9.4) (0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets~=7.7.0->primeqa==0.9.4) (1.5.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets~=7.7.0->primeqa==0.9.4) (0.6.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets~=7.7.0->primeqa==0.9.4) (5.0.1)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets~=7.7.0->primeqa==0.9.4) (0.7.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets~=7.7.0->primeqa==0.9.4) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets~=7.7.0->primeqa==0.9.4) (4.3.3)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets~=7.7.0->primeqa==0.9.4) (5.10.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets~=7.7.0->primeqa==0.9.4) (0.19.2)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert<6.0->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets~=7.7.0->primeqa==0.9.4) (0.5.1)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 6.3 MB/s
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 75.7 MB/s
#   Downloading multiprocess-0.70.12.2-py37-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 78.0 MB/s
#   Downloading multiprocess-0.70.12.1.zip (3.3 MB)
#      |████████████████████████████████| 3.3 MB 64.5 MB/s
#   Downloading multiprocess-0.70.12-py37-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 59.6 MB/s
#   Downloading multiprocess-0.70.11.1-py37-none-any.whl (108 kB)
#      |████████████████████████████████| 108 kB 76.0 MB/s
#   Downloading multiprocess-0.70.11-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 9.6 MB/s
#   Downloading multiprocess-0.70.10.zip (2.4 MB)
#      |████████████████████████████████| 2.4 MB 65.1 MB/s
#   Downloading multiprocess-0.70.9.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 58.6 MB/s
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from rouge-score->primeqa==0.9.4) (1.3.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy->onnxruntime>=1.8.1->pyserini~=0.16.0->primeqa==0.9.4) (1.2.1)
# Building wheels for collected packages: bitarray, dill, signals, docopt, emoji, multiprocess, rouge-score, sacremoses
#   Building wheel for bitarray (setup.py) ... done
#   Created wheel for bitarray: filename=bitarray-2.3.7-cp37-cp37m-linux_x86_64.whl size=173572 sha256=db5aef433905043d1145f506fb809d91a2545243cd074dc2a75ea10146248379
#   Stored in directory: /root/.cache/pip/wheels/91/65/b0/59479ecb406b1769a3126c2a633aad7365b956373d79724ef4
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78545 sha256=7134ae1ff00d8244dc85f46720ed7332d978bbcbfd25623218d913c4e3aa40e3
#   Stored in directory: /root/.cache/pip/wheels/a4/61/fd/c57e374e580aa78a45ed78d5859b3a44436af17e22ca53284f
#   Building wheel for signals (setup.py) ... done
#   Created wheel for signals: filename=signals-0.0.2-py3-none-any.whl size=2300 sha256=e71af54cf6a5f775ff576bd9c83c3b8665eb1a6b30be1e93cf9df8d41beff2f1
#   Stored in directory: /root/.cache/pip/wheels/94/ba/47/4cc03126fa8c8222b385c284a7a7814876c071261d13599f82
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=6166b73766503fe0e5c3eb91f952d62093284ae40321a7f9f14345bbec4047c0
#   Stored in directory: /root/.cache/pip/wheels/72/b0/3f/1d95f96ff986c7dfffe46ce2be4062f38ebd04b506c77c81b9
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-2.2.0-py3-none-any.whl size=234927 sha256=47e0cd684283fcdcaa6d5639e3ae8e0b2e4ff787b547baab59022f36592b320f
#   Stored in directory: /root/.cache/pip/wheels/f3/e3/f2/1de1c2e3ed742e1df73e0f15d58864e50c7e64f607b548d6cf
#   Building wheel for multiprocess (setup.py) ... done
#   Created wheel for multiprocess: filename=multiprocess-0.70.9-py3-none-any.whl size=108059 sha256=8d0877fdfdc7a90c4206a50a4cb18e270bdba2fe7edbae737ebe80d61e6d1e82
#   Stored in directory: /root/.cache/pip/wheels/83/2b/b4/50d7cae5b9069434454fd36da009832592af4fff58b51db8d9
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24954 sha256=80dc9e7a81b3f191d52a7ad8289172b46854763b559504d8402f0a96c551ae8f
#   Stored in directory: /root/.cache/pip/wheels/84/ac/6b/38096e3c5bf1dc87911e3585875e21a3ac610348e740409c76
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895259 sha256=8dce9f29e187487b121b541514cde5638d0453ab53617355fa13eac71310c33a
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
# Successfully built bitarray dill signals docopt emoji multiprocess rouge-score sacremoses
# Installing collected packages: typing-extensions, urllib3, tornado, matplotlib-inline, jedi, click, requests, pydantic, psutil, protobuf, nest-asyncio, ipython, humanfriendly, docopt, dill, zstandard, xxhash, tokenizers, thinc, smmap, sacremoses, responses, pymongo, pybind11, orjson, multiprocess, mdurl, ipykernel, huggingface-hub, hdfs, fastavro, coloredlogs, cloudpickle, transformers, torch, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, spacy, sentencepiece, pyjnius, pluggy, platformdirs, onnxruntime, nmslib, markdown-it-py, lightgbm, iniconfig, gitdb, emoji, distlib, datasets, coverage, apache-beam, virtualenv, ujson, stanza, sphinx, signals, rouge-score, pytest, pyserini, nlp, ninja, mdit-py-plugins, jsonlines, gitpython, frozendict, faiss-cpu, commonmark, bitarray, tox, sphinx-design, recommonmark, pytest-rerunfailures, pytest-mock, pytest-cov, pydata-sphinx-theme, primeqa, myst-parser, faiss-gpu, bump2version
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.0.4
#     Uninstalling tornado-6.0.4:
#       Successfully uninstalled tornado-6.0.4
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.2
#     Uninstalling pydantic-1.10.2:
#       Successfully uninstalled pydantic-1.10.2
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
#   Attempting uninstall: ipython
#     Found existing installation: ipython 7.9.0
#     Uninstalling ipython-7.9.0:
#       Successfully uninstalled ipython-7.9.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.6
#     Uninstalling dill-0.3.6:
#       Successfully uninstalled dill-0.3.6
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.5
#     Uninstalling thinc-8.1.5:
#       Successfully uninstalled thinc-8.1.5
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 4.3.2
#     Uninstalling pymongo-4.3.2:
#       Successfully uninstalled pymongo-4.3.2
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.3.4
#     Uninstalling ipykernel-5.3.4:
#       Successfully uninstalled ipykernel-5.3.4
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.5.0
#     Uninstalling cloudpickle-1.5.0:
#       Successfully uninstalled cloudpickle-1.5.0
#   Attempting uninstall: torch
#     Found existing installation: torch 1.12.1+cu113
#     Uninstalling torch-1.12.1+cu113:
#       Successfully uninstalled torch-1.12.1+cu113
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.4.2
#     Uninstalling spacy-3.4.2:
#       Successfully uninstalled spacy-3.4.2
#   Attempting uninstall: pluggy
#     Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
#   Attempting uninstall: lightgbm
#     Found existing installation: lightgbm 2.2.3
#     Uninstalling lightgbm-2.2.3:
#       Successfully uninstalled lightgbm-2.2.3
#   Attempting uninstall: sphinx
#     Found existing installation: Sphinx 1.8.6
#     Uninstalling Sphinx-1.8.6:
#       Successfully uninstalled Sphinx-1.8.6
#   Attempting uninstall: pytest
#     Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
#   Running setup.py develop for primeqa
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.13.1+cu113 requires torch==1.12.1, but you have torch 1.11.0 which is incompatible.
# torchtext 0.13.1 requires torch==1.12.1, but you have torch 1.11.0 which is incompatible.
# torchaudio 0.12.1+cu113 requires torch==1.12.1, but you have torch 1.11.0 which is incompatible.
# tensorflow 2.9.2 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# tensorboard 2.9.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=5.3.4, but you have ipykernel 6.13.1 which is incompatible.
# google-colab 1.0.0 requires ipython~=7.9.0, but you have ipython 7.34.0 which is incompatible.
# google-colab 1.0.0 requires tornado~=6.0.4, but you have tornado 6.2 which is incompatible.
# flask 1.1.4 requires click<8.0,>=5.1, but you have click 8.0.4 which is incompatible.
# en-core-web-sm 3.4.1 requires spacy<3.5.0,>=3.4.0, but you have spacy 3.2.4 which is incompatible.
# Successfully installed apache-beam-2.42.0 bitarray-2.3.7 bump2version-1.0.1 click-8.0.4 cloudpickle-2.1.0 coloredlogs-15.0.1 commonmark-0.9.1 coverage-6.5.0 datasets-2.3.2 dill-0.3.1.1 distlib-0.3.6 docopt-0.6.2 emoji-2.2.0 faiss-cpu-1.7.2 faiss-gpu-1.7.2 fastavro-1.7.0 frozendict-2.3.4 gitdb-4.0.9 gitpython-3.1.29 hdfs-2.7.0 huggingface-hub-0.10.1 humanfriendly-10.0 iniconfig-1.1.1 ipykernel-6.13.1 ipython-7.34.0 jedi-0.18.1 jsonlines-3.0.0 lightgbm-3.3.3 markdown-it-py-2.1.0 matplotlib-inline-0.1.6 mdit-py-plugins-0.3.1 mdurl-0.1.2 multiprocess-0.70.9 myst-parser-0.17.2 nest-asyncio-1.5.6 ninja-1.10.2.4 nlp-0.4.0 nmslib-2.1.1 onnxruntime-1.13.1 orjson-3.8.1 platformdirs-2.5.3 pluggy-1.0.0 primeqa protobuf-3.20.3 psutil-5.9.4 pybind11-2.6.1 pydantic-1.8.2 pydata-sphinx-theme-0.9.0 pyjnius-1.4.2 pymongo-3.13.0 pyserini-0.16.1 pytest-7.1.3 pytest-cov-3.0.0 pytest-mock-3.7.0 pytest-rerunfailures-10.2 recommonmark-0.7.1 requests-2.28.1 responses-0.18.0 rouge-score-0.1.2 sacremoses-0.0.53 sentencepiece-0.1.97 signals-0.0.2 smmap-5.0.0 spacy-3.2.4 sphinx-4.4.0 sphinx-design-0.2.0 sphinxcontrib-applehelp-1.0.2 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-2.0.0 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 stanza-1.4.2 thinc-8.0.17 tokenizers-0.13.2 torch-1.11.0 tornado-6.2 tox-3.24.5 transformers-4.17.0 typing-extensions-3.10.0.2 ujson-5.1.0 urllib3-1.26.12 virtualenv-20.16.6 xxhash-3.1.0 zstandard-0.19.0

# %%
# %cd /content/gdrive/MyDrive/experiments/primeqa
# Out:
# /content/gdrive/MyDrive/experiments/primeqa

# %%
# run PrimeQA SOTA MRC model on covid-qa test split. Finishes within 20m with a GPU.
# %run ./primeqa/mrc/run_mrc.py --model_name_or_path 'PrimeQA/squad-v1-roberta-large' --max_seq_length 512 --eval_file './data/reader_data/covidqa_test_split.json' --output_dir './output_data/mrc_512_output_org' --fp16 --do_eval --per_device_eval_batch_size 128 --overwrite_output_dir --overwrite_cache --dataset_name squad --dataset_config_name plain_text --preprocessor primeqa.mrc.processors.preprocessors.squad.SQUADPreprocessor --postprocessor primeqa.mrc.processors.postprocessors.squad.SQUADPostProcessor --eval_metrics SQUAD
# Out:
# Downloading:   0%|          | 0.00/774 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/780k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# WARNING:datasets.builder:Using custom data configuration default-6022dbaef0303d4c
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-6022dbaef0303d4c/0.0.0/da492aad5680612e4028e7f6ddc04b1dfcec4b64db470ed7cc5f2bb265b9b6b5...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-6022dbaef0303d4c/0.0.0/da492aad5680612e4028e7f6ddc04b1dfcec4b64db470ed7cc5f2bb265b9b6b5. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1019 [00:00<?, ?ex/s]
# Running tokenizer on eval dataset:   0%|          | 0/2 [00:00<?, ?ba/s]
# Using amp half precision backend
# ***** Running Evaluation *****
#   Num examples = 20795
#   Batch size = 128
#     <div>
#
#       <progress value='163' max='163' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [163/163 13:45]
#     </div>
# 100%|██████████| 1019/1019 [01:01<00:00, 16.69it/s]
# 100%|██████████| 1019/1019 [00:00<00:00, 4438.23it/s]
# ***** eval metrics *****
#   eval_exact_match = 28.3611
#   eval_f1          =  50.166
#   eval_samples     =    1019

# %%
# finetune PrimeQA SOTA MRC model with covid-qa train data set. Takes about 1h49mins.
# check if you need to reduce train batch size to 1 to fit the train mini-batches
# %run ./primeqa/mrc/run_mrc.py --model_name_or_path 'PrimeQA/squad-v1-roberta-large' --max_seq_length 512 --train_file './data/reader_data/covidqa_train_split.json' --output_dir './output_data/mrc_512_finetune_org' --fp16 --learning_rate 4e-5 --do_train --per_device_train_batch_size 1 --gradient_accumulation_steps 16 --warmup_ratio 0.1 --weight_decay 0.1 --save_steps 50000 --overwrite_output_dir --num_train_epochs 2 --evaluation_strategy no --overwrite_cache --dataset_name squad --dataset_config_name plain_text --preprocessor primeqa.mrc.processors.preprocessors.squad.SQUADPreprocessor --postprocessor primeqa.mrc.processors.postprocessors.squad.SQUADPostProcessor
# Out:
# Downloading:   0%|          | 0.00/774 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/780k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# WARNING:datasets.builder:Using custom data configuration default-f801547a992e8122
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-f801547a992e8122/0.0.0/da492aad5680612e4028e7f6ddc04b1dfcec4b64db470ed7cc5f2bb265b9b6b5...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-f801547a992e8122/0.0.0/da492aad5680612e4028e7f6ddc04b1dfcec4b64db470ed7cc5f2bb265b9b6b5. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?ex/s]
# Running tokenizer on train dataset:   0%|          | 0/1 [00:00<?, ?ba/s]
# Using amp half precision backend
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 19987
#   Num Epochs = 2
#   Instantaneous batch size per device = 1
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 16
#   Total optimization steps = 2498
#     <div>
#
#       <progress value='2498' max='2498' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2498/2498 1:47:51, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.505800</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.263000</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.202900</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.159400</td>
#     </tr>
#   </tbody>
# </table><p>
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Saving model checkpoint to ./output_data/mrc_512_finetune_org
# Configuration saved in ./output_data/mrc_512_finetune_org/config.json
# Model weights saved in ./output_data/mrc_512_finetune_org/pytorch_model.bin
# tokenizer config file saved in ./output_data/mrc_512_finetune_org/tokenizer_config.json
# Special tokens file saved in ./output_data/mrc_512_finetune_org/special_tokens_map.json
# ***** train metrics *****
#   epoch                    =        2.0
#   total_flos               = 34421577GF
#   train_loss               =      0.257
#   train_runtime            = 1:47:53.90
#   train_samples            =      19987
#   train_samples_per_second =      6.175
#   train_steps_per_second   =      0.386

# %%
# Run inference with the above trained reader and see how high the scores are
# %run ./primeqa/mrc/run_mrc.py --model_name_or_path './output_data/mrc_512_finetune_org' --max_seq_length 512 --eval_file './data/reader_data/covidqa_test_split.json' --output_dir './data/finetuned_output_512_org' --fp16 --do_eval --per_device_eval_batch_size 128 --overwrite_output_dir --overwrite_cache --dataset_name squad --dataset_config_name plain_text --preprocessor primeqa.mrc.processors.preprocessors.squad.SQUADPreprocessor --postprocessor primeqa.mrc.processors.postprocessors.squad.SQUADPostProcessor --eval_metrics SQUAD
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# loading configuration file ./output_data/mrc_512_finetune_org/config.json
# Model config RobertaConfig {
#   "_name_or_path": "./output_data/mrc_512_finetune_org",
#   "architectures": [
#     "RobertaModelForDownstreamTasks"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "decoding_times_with_dropout": 5,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_dropout_rate": 0.25,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "sep_token_id": 2,
#   "torch_dtype": "float32",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# Didn't find file ./output_data/mrc_512_finetune_org/added_tokens.json. We won't load it.
# loading file ./output_data/mrc_512_finetune_org/vocab.json
# loading file ./output_data/mrc_512_finetune_org/merges.txt
# loading file ./output_data/mrc_512_finetune_org/tokenizer.json
# loading file None
# loading file ./output_data/mrc_512_finetune_org/special_tokens_map.json
# loading file ./output_data/mrc_512_finetune_org/tokenizer_config.json
# loading weights file ./output_data/mrc_512_finetune_org/pytorch_model.bin
# All model checkpoint weights were used when initializing RobertaModelForDownstreamTasks.
#
# All the weights of RobertaModelForDownstreamTasks were initialized from the model checkpoint at ./output_data/mrc_512_finetune_org.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaModelForDownstreamTasks for predictions without further training.
# WARNING:datasets.builder:Using custom data configuration default-6022dbaef0303d4c
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-6022dbaef0303d4c/0.0.0/da492aad5680612e4028e7f6ddc04b1dfcec4b64db470ed7cc5f2bb265b9b6b5...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-6022dbaef0303d4c/0.0.0/da492aad5680612e4028e7f6ddc04b1dfcec4b64db470ed7cc5f2bb265b9b6b5. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1019 [00:00<?, ?ex/s]
# Running tokenizer on eval dataset:   0%|          | 0/2 [00:00<?, ?ba/s]
# Using amp half precision backend
# ***** Running Evaluation *****
#   Num examples = 20795
#   Batch size = 128
#     <div>
#
#       <progress value='163' max='163' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [163/163 15:20]
#     </div>
# 100%|██████████| 1019/1019 [00:58<00:00, 17.56it/s]
# 100%|██████████| 1019/1019 [00:00<00:00, 4325.06it/s]
# ***** eval metrics *****
#   eval_exact_match = 36.3101
#   eval_f1          = 64.6265
#   eval_samples     =    1019

# %%
# use the next cell command for latest run_ir changes with simplified colBERT usage.
# run Retriever to get the top docs for your test queries
#%run  ./primeqa/ir/run_ir.py --do_search --engine_type ColBERT --amp --doc_maxlen 512 --bsize 16 --retrieve_only --queries './data/retriever_data/test_queries.tsv' --checkpoint './data/retriever_data/retriever.model' --root '/content/gdrive/MyDrive/primeqa/' --experiment 'data' --index_root '/content/gdrive/MyDrive/primeqa/data/indexes/covidqa_index_512' --index_name 'covidqa_index_512' --ranks_fn '/content/gdrive/MyDrive/primeqa/data/retriever_data/output/scores_and_ranks.tsv'

# %%
# run Retriever to get the top docs for your test queries
# %run  ./primeqa/ir/run_ir.py --do_search --engine_type ColBERT --doc_maxlen 512 --bsize 16 --retrieve_only --queries './data/retriever_data/test_queries.tsv' --model_name_or_path './data/retriever_data/retriever.model' --index_location './data/retriever_data/covidqa_index' --output_dir './data/retriever_data/output'

# %%
# run the reader with retrieved docs. However, this reader has no access to target domain data
# %run ./primeqa/mrc/run_mrc.py --model_name_or_path 'PrimeQA/squad-v1-roberta-large' --max_seq_length 512 --eval_file './data/reader_data/covidqa_test_split_with_ir_passages.json' --output_dir './data/output/mrc_512_output_ir' --fp16 --do_eval --per_device_eval_batch_size 128 --overwrite_output_dir --overwrite_cache --dataset_name squad --dataset_config_name plain_text --preprocessor primeqa.mrc.processors.preprocessors.squad.SQUADPreprocessor --postprocessor primeqa.mrc.processors.postprocessors.squad.SQUADPostProcessor --eval_metrics SQUAD
# Out:
# Downloading:   0%|          | 0.00/774 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/780k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.01M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# WARNING:datasets.builder:Using custom data configuration default-17a73942b4694424
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-17a73942b4694424/0.0.0/da492aad5680612e4028e7f6ddc04b1dfcec4b64db470ed7cc5f2bb265b9b6b5...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-17a73942b4694424/0.0.0/da492aad5680612e4028e7f6ddc04b1dfcec4b64db470ed7cc5f2bb265b9b6b5. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1019 [00:00<?, ?ex/s]
# Running tokenizer on eval dataset:   0%|          | 0/2 [00:00<?, ?ba/s]
# Using amp half precision backend
# ***** Running Evaluation *****
#   Num examples = 18165
#   Batch size = 128
#     <div>
#
#       <progress value='142' max='142' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [142/142 11:53]
#     </div>
# 100%|██████████| 1019/1019 [00:56<00:00, 18.01it/s]
# 100%|██████████| 1019/1019 [00:00<00:00, 4821.69it/s]
# ***** eval metrics *****
#   eval_exact_match =  10.893
#   eval_f1          = 22.0026
#   eval_samples     =    1019

# %%
# run the reader with retrieved docs.
#This reader was fine-tuned with target domain data (performance should get better)
# %run ./primeqa/mrc/run_mrc.py --model_name_or_path './output_data/mrc_512_finetune_org' --max_seq_length 512 --eval_file './data/reader_data/covidqa_test_split_with_ir_passages.json' --output_dir './output_data/finetuned_mrc_512_output_ir' --fp16 --do_eval --per_device_eval_batch_size 128 --overwrite_output_dir --overwrite_cache --dataset_name squad --dataset_config_name plain_text --preprocessor primeqa.mrc.processors.preprocessors.squad.SQUADPreprocessor --postprocessor primeqa.mrc.processors.postprocessors.squad.SQUADPostProcessor --eval_metrics SQUAD
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# loading configuration file ./output_data/mrc_512_finetune_org/config.json
# Model config RobertaConfig {
#   "_name_or_path": "./output_data/mrc_512_finetune_org",
#   "architectures": [
#     "RobertaModelForDownstreamTasks"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "decoding_times_with_dropout": 5,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "output_dropout_rate": 0.25,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "sep_token_id": 2,
#   "torch_dtype": "float32",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 50265
# }
#
# Didn't find file ./output_data/mrc_512_finetune_org/added_tokens.json. We won't load it.
# loading file ./output_data/mrc_512_finetune_org/vocab.json
# loading file ./output_data/mrc_512_finetune_org/merges.txt
# loading file ./output_data/mrc_512_finetune_org/tokenizer.json
# loading file None
# loading file ./output_data/mrc_512_finetune_org/special_tokens_map.json
# loading file ./output_data/mrc_512_finetune_org/tokenizer_config.json
# loading weights file ./output_data/mrc_512_finetune_org/pytorch_model.bin
# All model checkpoint weights were used when initializing RobertaModelForDownstreamTasks.
#
# All the weights of RobertaModelForDownstreamTasks were initialized from the model checkpoint at ./output_data/mrc_512_finetune_org.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaModelForDownstreamTasks for predictions without further training.
# WARNING:datasets.builder:Using custom data configuration default-17a73942b4694424
# Downloading and preparing dataset json/default to /root/.cache/huggingface/datasets/json/default-17a73942b4694424/0.0.0/da492aad5680612e4028e7f6ddc04b1dfcec4b64db470ed7cc5f2bb265b9b6b5...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# 0 tables [00:00, ? tables/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/json/default-17a73942b4694424/0.0.0/da492aad5680612e4028e7f6ddc04b1dfcec4b64db470ed7cc5f2bb265b9b6b5. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1019 [00:00<?, ?ex/s]
# Running tokenizer on eval dataset:   0%|          | 0/2 [00:00<?, ?ba/s]
# Using amp half precision backend
# ***** Running Evaluation *****
#   Num examples = 18165
#   Batch size = 128
#     <div>
#
#       <progress value='142' max='142' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [142/142 13:23]
#     </div>
# 100%|██████████| 1019/1019 [00:50<00:00, 20.19it/s]
# 100%|██████████| 1019/1019 [00:00<00:00, 4629.39it/s]
# ***** eval metrics *****
#   eval_exact_match = 14.1315
#   eval_f1          = 26.9275
#   eval_samples     =    1019
